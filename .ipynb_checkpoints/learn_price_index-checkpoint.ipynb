# %%
import os
import pandas as pd

root_path = "log_files"

all_data = []
start_kw = "Starting a new Game, game #"
day_kw = "Day: "
stats_kw = "Statistics: "
campaign_kw = "[startDay ="
qs_hw = "Quality Score"
profit_kw = "Cumulative Profit: "

folders = [i for i in os.listdir(root_path) if i[0] != "."]
print(folders)
for folder in folders:
    file_names = os.listdir(os.path.join(root_path, folder))
    for file_ in file_names:
        full_path = os.path.join(root_path, folder, file_)
        txt_num = file_.split(".")[0]

        with open(full_path, "r") as file:
            data_ = file.readlines()

            curr_game = 0
            curr_day = 0

            for line_ in data_:
                if start_kw in line_:
                    curr_game = int(
                        line_[line_.index(start_kw)+len(start_kw):])
                if day_kw in line_:
                    curr_day = int(
                        line_[line_.index(day_kw)+len(day_kw):-2])
                if stats_kw in line_:
                    if "null" in line_:
                        curr_stats = 0
                        price = 0
                    else:
                        curr_stats = line_[line_.index(stats_kw) + len(stats_kw):-1]
                        no_impressions = curr_stats[curr_stats.index("(") + 1:curr_stats.index(",")]
                        no_payment = curr_stats[curr_stats.index(",") + 2:curr_stats.index(")")]
                        price =  float(no_payment) / float(no_impressions)
                        
                if campaign_kw in line_:
                    curr_campaign = line_[line_.index(campaign_kw):]
                    curr_segment = curr_campaign[curr_campaign.index("Segment = ") + len("Segment = "): 
                                                curr_campaign.index("Reach = ")-2]
                if qs_hw in line_:
                    curr_qs = line_[line_.index(qs_hw) + len(qs_hw):-1]
                if profit_kw in line_:
                    curr_profit = line_[line_.index(profit_kw) + len(profit_kw):-1]
                    all_data.append([txt_num, curr_game, curr_day, curr_stats, price, curr_segment, curr_qs, curr_profit])
# Out:
# ['2020-04-28', '2020-04-26', '2020-04-27', '2020-04-29', '2020-04-25', '2020-05-01', '2020-04-30']
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-23-041b0fa024e0> in <module>
#      41                         no_impressions = curr_stats[curr_stats.index("(") + 1:curr_stats.index(",")]
#      42                         no_payment = curr_stats[curr_stats.index(",") + 2:curr_stats.index(")")]
# ---> 43                         price = float(no_impressions) / float(no_payment)
#      44
#      45                 if campaign_kw in line_:
#
# ZeroDivisionError: float division by zero

# %%
df = pd.DataFrame(all_data, columns = ["txt_num", "game", "day", "stats", "price_index", "segment", "quality_score", "cumulative_profit"])

# %%
df[df["stats"] != 0]
# Out:
#       txt_num  game  day                            stats  \
# 1        2200     1    2                 {3=(1837, 0.0)},
# 2        2200     1    3    {3=(1845, 92.2499999999969)},
# 3        2200     1    4  {3=(1813, 167.87162592795502)},
# 12       2200     2    2                {3=(594, 594.0)},
# 23       2200     3    2                 {3=(2367, 0.0)},
# ...       ...   ...  ...                              ...
# 55507    1300    47    2              {7=(1174, 1174.0)},
# 55508    1300    47    3   {7=(247, 19.760489343089386)},
# 55518    1300    48    2               {7=(2603, 784.0)},
# 55529    1300    49    2                {7=(397, 397.0)},
# 55540    1300    50    2    {7=(427, 42.70000000000034)},
#
#                                                 campaign  \
# 1      [startDay = 1, endDay = 3, Segment = MALE_OLD_...
# 2      [startDay = 1, endDay = 3, Segment = MALE_OLD_...
# 3      [startDay = 1, endDay = 3, Segment = MALE_OLD_...
# 12     [startDay = 1, endDay = 1, Segment = FEMALE_YO...
# 23     [startDay = 1, endDay = 3, Segment = FEMALE_OL...
# ...                                                  ...
# 55507  [startDay = 1, endDay = 2, Segment = FEMALE_OL...
# 55508  [startDay = 1, endDay = 2, Segment = FEMALE_OL...
# 55518  [startDay = 1, endDay = 1, Segment = OLD_LOW_I...
# 55529  [startDay = 1, endDay = 1, Segment = MALE_HIGH...
# 55540  [startDay = 1, endDay = 1, Segment = FEMALE_OL...
#
#                quality_score      cumulative_profit
# 1                      = 1.0      787.7478972431743
# 2                      = 1.0      3585.372304865352
# 3       = 1.1101766763089793      4339.390160089134
# 12      = 0.9999805623844686   -0.02309188725121203
# 23                     = 1.0      842.2061258902104
# ...                      ...                    ...
# 55507                  = 1.0     -668.7417114255531
# 55508    = 0.663669661145653     -407.8187765216638
# 55518   = 1.1471330776412647       844.186823345422
# 55529   = 0.9999805623844686  -0.015433466731906265
# 55540    = 1.170441092690051      120.8876266163721
#
# [10120 rows x 7 columns]

# %%
df.campaign.unique()
# Out:
# array(['[startDay = 1, endDay = 3, Segment = MALE_OLD_LOW_INCOME, Reach = 3769, Budget = 3769.0]\n',
#        '[startDay = 1, endDay = 1, Segment = FEMALE_YOUNG_LOW_INCOME, Reach = 594, Budget = 594.0]\n',
#        '[startDay = 1, endDay = 3, Segment = FEMALE_OLD, Reach = 5896, Budget = 5896.0]\n',
#        '[startDay = 1, endDay = 3, Segment = MALE_YOUNG, Reach = 4941, Budget = 4941.0]\n',
#        '[startDay = 1, endDay = 1, Segment = MALE_YOUNG_HIGH_INCOME, Reach = 258, Budget = 258.0]\n',
#        '[startDay = 1, endDay = 3, Segment = FEMALE_OLD_HIGH_INCOME, Reach = 610, Budget = 610.0]\n',
#        '[startDay = 1, endDay = 3, Segment = FEMALE_HIGH_INCOME, Reach = 596, Budget = 596.0]\n',
#        '[startDay = 1, endDay = 1, Segment = OLD_LOW_INCOME, Reach = 1258, Budget = 1258.0]\n',
#        '[startDay = 1, endDay = 2, Segment = FEMALE_HIGH_INCOME, Reach = 663, Budget = 663.0]\n',
#        '[startDay = 1, endDay = 3, Segment = MALE_YOUNG_LOW_INCOME, Reach = 1652, Budget = 1652.0]\n',
#        '[startDay = 1, endDay = 2, Segment = FEMALE_OLD, Reach = 3931, Budget = 3931.0]\n',
#        '[startDay = 1, endDay = 3, Segment = MALE_LOW_INCOME, Reach = 5446, Budget = 5446.0]\n',
#        '[startDay = 1, endDay = 3, Segment = MALE_LOW_INCOME, Reach = 3267, Budget = 3267.0]\n',
#        '[startDay = 1, endDay = 1, Segment = MALE_OLD_HIGH_INCOME, Reach = 565, Budget = 565.0]\n',
#        '[startDay = 1, endDay = 1, Segment = FEMALE_YOUNG_LOW_INCOME, Reach = 990, Budget = 990.0]\n',
#        '[startDay = 1, endDay = 2, Segment = FEMALE_OLD_HIGH_INCOME, Reach = 407, Budget = 407.0]\n',
#        '[startDay = 1, endDay = 3, Segment = FEMALE_LOW_INCOME, Reach = 3942, Budget = 3942.0]\n',
#        '[startDay = 1, endDay = 2, Segment = YOUNG_LOW_INCOME, Reach = 3816, Budget = 3816.0]\n',
#        '[startDay = 1, endDay = 3, Segment = MALE_YOUNG, Reach = 2117, Budget = 2117.0]\n',
#        '[startDay = 1, endDay = 3, Segment = MALE_YOUNG_LOW_INCOME, Reach = 2754, Budget = 2754.0]\n',
#        '[startDay = 1, endDay = 1, Segment = MALE_OLD_HIGH_INCOME, Reach = 404, Budget = 404.0]\n',
#        '[startDay = 1, endDay = 3, Segment = FEMALE_LOW_INCOME, Reach = 6571, Budget = 6571.0]\n',
#        '[startDay = 1, endDay = 2, Segment = MALE_YOUNG_LOW_INCOME, Reach = 2570, Budget = 2570.0]\n',
#        '[startDay = 1, endDay = 3, Segment = MALE_HIGH_INCOME, Reach = 1192, Budget = 1192.0]\n',
#        '[startDay = 1, endDay = 3, Segment = FEMALE_YOUNG, Reach = 3354, Budget = 3354.0]\n',
#        '[startDay = 1, endDay = 3, Segment = FEMALE_OLD_LOW_INCOME, Reach = 3601, Budget = 3601.0]\n',
#        '[startDay = 1, endDay = 2, Segment = FEMALE_YOUNG, Reach = 2236, Budget = 2236.0]\n',
#        '[startDay = 1, endDay = 3, Segment = MALE_HIGH_INCOME, Reach = 1987, Budget = 1987.0]\n',
#        '[startDay = 1, endDay = 2, Segment = FEMALE_LOW_INCOME, Reach = 2628, Budget = 2628.0]\n',
#        '[startDay = 1, endDay = 3, Segment = YOUNG_LOW_INCOME, Reach = 5724, Budget = 5724.0]\n',
#        '[startDay = 1, endDay = 1, Segment = FEMALE_HIGH_INCOME, Reach = 198, Budget = 198.0]\n',
#        '[startDay = 1, endDay = 2, Segment = FEMALE_YOUNG_LOW_INCOME, Reach = 1980, Budget = 1980.0]\n',
#        '[startDay = 1, endDay = 2, Segment = MALE_OLD_HIGH_INCOME, Reach = 808, Budget = 808.0]\n',
#        '[startDay = 1, endDay = 2, Segment = FEMALE_OLD_LOW_INCOME, Reach = 1440, Budget = 1440.0]\n',
#        '[startDay = 1, endDay = 3, Segment = FEMALE_YOUNG_HIGH_INCOME, Reach = 230, Budget = 230.0]\n',
#        '[startDay = 1, endDay = 2, Segment = MALE_OLD_HIGH_INCOME, Reach = 1131, Budget = 1131.0]\n',
#        '[startDay = 1, endDay = 3, Segment = YOUNG_HIGH_INCOME, Reach = 1159, Budget = 1159.0]\n',
#        '[startDay = 1, endDay = 2, Segment = FEMALE_YOUNG_LOW_INCOME, Reach = 2772, Budget = 2772.0]\n',
#        '[startDay = 1, endDay = 1, Segment = FEMALE_YOUNG, Reach = 1118, Budget = 1118.0]\n',
#        '[startDay = 1, endDay = 1, Segment = FEMALE_OLD, Reach = 842, Budget = 842.0]\n',
#        '[startDay = 1, endDay = 2, Segment = FEMALE_YOUNG_HIGH_INCOME, Reach = 256, Budget = 256.0]\n',
#        '[startDay = 1, endDay = 1, Segment = MALE_OLD, Reach = 1822, Budget = 1822.0]\n',
#        '[startDay = 1, endDay = 2, Segment = MALE_OLD_LOW_INCOME, Reach = 1077, Budget = 1077.0]\n',
#        '[startDay = 1, endDay = 1, Segment = OLD_HIGH_INCOME, Reach = 850, Budget = 850.0]\n',
#        '[startDay = 1, endDay = 1, Segment = FEMALE_HIGH_INCOME, Reach = 464, Budget = 464.0]\n',
#        '[startDay = 1, endDay = 1, Segment = FEMALE_OLD_LOW_INCOME, Reach = 720, Budget = 720.0]\n',
#        '[startDay = 1, endDay = 1, Segment = MALE_OLD_HIGH_INCOME, Reach = 242, Budget = 242.0]\n',
#        '[startDay = 1, endDay = 1, Segment = YOUNG_LOW_INCOME, Reach = 1144, Budget = 1144.0]\n',
#        '[startDay = 1, endDay = 3, Segment = FEMALE_YOUNG_LOW_INCOME, Reach = 4158, Budget = 4158.0]\n',
#        '[startDay = 1, endDay = 1, Segment = FEMALE_OLD_HIGH_INCOME, Reach = 284, Budget = 284.0]\n',
#        '[startDay = 1, endDay = 1, Segment = MALE_OLD_LOW_INCOME, Reach = 1256, Budget = 1256.0]\n',
#        '[startDay = 1, endDay = 2, Segment = OLD_HIGH_INCOME, Reach = 729, Budget = 729.0]\n',
#        '[startDay = 1, endDay = 3, Segment = MALE_OLD, Reach = 5466, Budget = 5466.0]\n',
#        '[startDay = 1, endDay = 2, Segment = MALE_OLD, Reach = 3644, Budget = 3644.0]\n',
#        '[startDay = 1, endDay = 1, Segment = OLD_HIGH_INCOME, Reach = 364, Budget = 364.0]\n',
#        '[startDay = 1, endDay = 3, Segment = FEMALE_LOW_INCOME, Reach = 9200, Budget = 9200.0]\n',
#        '[startDay = 1, endDay = 1, Segment = MALE_LOW_INCOME, Reach = 1815, Budget = 1815.0]\n',
#        '[startDay = 1, endDay = 1, Segment = MALE_LOW_INCOME, Reach = 1089, Budget = 1089.0]\n',
#        '[startDay = 1, endDay = 2, Segment = FEMALE_OLD_LOW_INCOME, Reach = 2401, Budget = 2401.0]\n',
#        '[startDay = 1, endDay = 1, Segment = OLD_LOW_INCOME, Reach = 2098, Budget = 2098.0]\n',
#        '[startDay = 1, endDay = 3, Segment = FEMALE_OLD_LOW_INCOME, Reach = 2160, Budget = 2160.0]\n',
#        '[startDay = 1, endDay = 2, Segment = YOUNG_LOW_INCOME, Reach = 2289, Budget = 2289.0]\n',
#        '[startDay = 1, endDay = 1, Segment = FEMALE_YOUNG_LOW_INCOME, Reach = 1386, Budget = 1386.0]\n',
#        '[startDay = 9, endDay = 9, Segment = OLD_HIGH_INCOME, Reach = 850, Budget = 286.09017609538216]\n',
#        '[startDay = 10, endDay = 10, Segment = FEMALE_YOUNG_HIGH_INCOME, Reach = 179, Budget = 58.873342077002114]\n',
#        '[startDay = 1, endDay = 2, Segment = MALE_LOW_INCOME, Reach = 3631, Budget = 3631.0]\n',
#        '[startDay = 1, endDay = 2, Segment = FEMALE_OLD_HIGH_INCOME, Reach = 569, Budget = 569.0]\n',
#        '[startDay = 1, endDay = 2, Segment = FEMALE_YOUNG, Reach = 3130, Budget = 3130.0]\n',
#        '[startDay = 1, endDay = 1, Segment = YOUNG_LOW_INCOME, Reach = 1908, Budget = 1908.0]\n',
#        '[startDay = 1, endDay = 2, Segment = FEMALE_LOW_INCOME, Reach = 6133, Budget = 6133.0]\n',
#        '[startDay = 1, endDay = 2, Segment = YOUNG_LOW_INCOME, Reach = 5342, Budget = 5342.0]\n',
#        '[startDay = 1, endDay = 3, Segment = MALE_OLD_HIGH_INCOME, Reach = 1212, Budget = 1212.0]\n',
#        '[startDay = 1, endDay = 1, Segment = FEMALE_OLD_LOW_INCOME, Reach = 1680, Budget = 1680.0]\n',
#        '[startDay = 1, endDay = 2, Segment = MALE_OLD, Reach = 1561, Budget = 1561.0]\n',
#        '[startDay = 1, endDay = 3, Segment = MALE_HIGH_INCOME, Reach = 2782, Budget = 2782.0]\n',
#        '[startDay = 1, endDay = 1, Segment = MALE_HIGH_INCOME, Reach = 662, Budget = 662.0]\n',
#        '[startDay = 1, endDay = 1, Segment = MALE_YOUNG_LOW_INCOME, Reach = 1285, Budget = 1285.0]\n',
#        '[startDay = 1, endDay = 1, Segment = MALE_YOUNG_LOW_INCOME, Reach = 918, Budget = 918.0]\n',
#        '[startDay = 1, endDay = 3, Segment = OLD_HIGH_INCOME, Reach = 1822, Budget = 1822.0]\n',
#        '[startDay = 1, endDay = 1, Segment = MALE_HIGH_INCOME, Reach = 927, Budget = 927.0]\n',
#        '[startDay = 1, endDay = 1, Segment = FEMALE_YOUNG_HIGH_INCOME, Reach = 179, Budget = 179.0]\n',
#        '[startDay = 1, endDay = 1, Segment = FEMALE_YOUNG_HIGH_INCOME, Reach = 76, Budget = 76.0]\n',
#        '[startDay = 1, endDay = 1, Segment = MALE_YOUNG_HIGH_INCOME, Reach = 155, Budget = 155.0]\n',
#        '[startDay = 1, endDay = 1, Segment = FEMALE_HIGH_INCOME, Reach = 331, Budget = 331.0]\n',
#        '[startDay = 1, endDay = 3, Segment = FEMALE_OLD, Reach = 2527, Budget = 2527.0]\n',
#        '[startDay = 1, endDay = 3, Segment = FEMALE_HIGH_INCOME, Reach = 1392, Budget = 1392.0]\n',
#        '[startDay = 1, endDay = 2, Segment = FEMALE_YOUNG_HIGH_INCOME, Reach = 358, Budget = 358.0]\n',
#        '[startDay = 1, endDay = 1, Segment = FEMALE_OLD, Reach = 1965, Budget = 1965.0]\n',
#        '[startDay = 1, endDay = 1, Segment = YOUNG_HIGH_INCOME, Reach = 231, Budget = 231.0]\n',
#        '[startDay = 1, endDay = 1, Segment = MALE_OLD, Reach = 780, Budget = 780.0]\n',
#        '[startDay = 1, endDay = 3, Segment = OLD_LOW_INCOME, Reach = 3776, Budget = 3776.0]\n',
#        '[startDay = 1, endDay = 3, Segment = FEMALE_YOUNG, Reach = 2012, Budget = 2012.0]\n',
#        '[startDay = 1, endDay = 3, Segment = YOUNG_LOW_INCOME, Reach = 3434, Budget = 3434.0]\n',
#        '[startDay = 1, endDay = 2, Segment = YOUNG_HIGH_INCOME, Reach = 463, Budget = 463.0]\n',
#        '[startDay = 1, endDay = 1, Segment = MALE_OLD_LOW_INCOME, Reach = 897, Budget = 897.0]\n',
#        '[startDay = 1, endDay = 3, Segment = MALE_YOUNG_HIGH_INCOME, Reach = 1085, Budget = 1085.0]\n',
#        '[startDay = 1, endDay = 3, Segment = FEMALE_YOUNG_LOW_INCOME, Reach = 2970, Budget = 2970.0]\n',
#        '[startDay = 1, endDay = 3, Segment = FEMALE_OLD_LOW_INCOME, Reach = 5042, Budget = 5042.0]\n',
#        '[startDay = 1, endDay = 2, Segment = FEMALE_YOUNG_LOW_INCOME, Reach = 1188, Budget = 1188.0]\n',
#        '[startDay = 1, endDay = 1, Segment = YOUNG_HIGH_INCOME, Reach = 386, Budget = 386.0]\n',
#        '[startDay = 1, endDay = 1, Segment = MALE_YOUNG_HIGH_INCOME, Reach = 361, Budget = 361.0]\n',
#        '[startDay = 1, endDay = 3, Segment = MALE_OLD_HIGH_INCOME, Reach = 1696, Budget = 1696.0]\n',
#        '[startDay = 1, endDay = 1, Segment = FEMALE_OLD_LOW_INCOME, Reach = 1200, Budget = 1200.0]\n',
#        '[startDay = 1, endDay = 2, Segment = MALE_HIGH_INCOME, Reach = 1325, Budget = 1325.0]\n',
#        '[startDay = 1, endDay = 3, Segment = FEMALE_YOUNG_HIGH_INCOME, Reach = 384, Budget = 384.0]\n',
#        '[startDay = 1, endDay = 1, Segment = MALE_OLD_LOW_INCOME, Reach = 538, Budget = 538.0]\n',
#        '[startDay = 1, endDay = 3, Segment = YOUNG_HIGH_INCOME, Reach = 695, Budget = 695.0]\n',
#        '[startDay = 1, endDay = 1, Segment = MALE_HIGH_INCOME, Reach = 397, Budget = 397.0]\n',
#        '[startDay = 1, endDay = 3, Segment = MALE_OLD_HIGH_INCOME, Reach = 727, Budget = 727.0]\n',
#        '[startDay = 1, endDay = 2, Segment = OLD_LOW_INCOME, Reach = 5874, Budget = 5874.0]\n',
#        '[startDay = 1, endDay = 3, Segment = FEMALE_OLD, Reach = 4212, Budget = 4212.0]\n',
#        '[startDay = 1, endDay = 2, Segment = OLD_HIGH_INCOME, Reach = 1701, Budget = 1701.0]\n',
#        '[startDay = 1, endDay = 1, Segment = YOUNG_HIGH_INCOME, Reach = 541, Budget = 541.0]\n',
#        '[startDay = 1, endDay = 3, Segment = MALE_YOUNG_HIGH_INCOME, Reach = 775, Budget = 775.0]\n',
#        '[startDay = 1, endDay = 2, Segment = MALE_YOUNG, Reach = 2353, Budget = 2353.0]\n',
#        '[startDay = 1, endDay = 2, Segment = MALE_OLD_LOW_INCOME, Reach = 2513, Budget = 2513.0]\n',
#        '[startDay = 1, endDay = 1, Segment = MALE_YOUNG, Reach = 705, Budget = 705.0]\n',
#        '[startDay = 1, endDay = 1, Segment = FEMALE_LOW_INCOME, Reach = 3066, Budget = 3066.0]\n',
#        '[startDay = 1, endDay = 2, Segment = FEMALE_OLD_LOW_INCOME, Reach = 3361, Budget = 3361.0]\n',
#        '[startDay = 1, endDay = 1, Segment = MALE_LOW_INCOME, Reach = 2541, Budget = 2541.0]\n',
#        '[startDay = 1, endDay = 3, Segment = YOUNG_HIGH_INCOME, Reach = 1623, Budget = 1623.0]\n',
#        '[startDay = 1, endDay = 3, Segment = MALE_OLD_LOW_INCOME, Reach = 2692, Budget = 2692.0]\n',
#        '[startDay = 1, endDay = 2, Segment = MALE_HIGH_INCOME, Reach = 1854, Budget = 1854.0]\n',
#        '[startDay = 1, endDay = 3, Segment = FEMALE_OLD_HIGH_INCOME, Reach = 366, Budget = 366.0]\n',
#        '[startDay = 1, endDay = 1, Segment = FEMALE_YOUNG, Reach = 670, Budget = 670.0]\n',
#        '[startDay = 1, endDay = 2, Segment = FEMALE_OLD_HIGH_INCOME, Reach = 244, Budget = 244.0]\n',
#        '[startDay = 1, endDay = 1, Segment = OLD_HIGH_INCOME, Reach = 607, Budget = 607.0]\n',
#        '[startDay = 1, endDay = 1, Segment = YOUNG_LOW_INCOME, Reach = 2671, Budget = 2671.0]\n',
#        '[startDay = 1, endDay = 2, Segment = MALE_HIGH_INCOME, Reach = 795, Budget = 795.0]\n',
#        '[startDay = 1, endDay = 3, Segment = MALE_OLD_LOW_INCOME, Reach = 1615, Budget = 1615.0]\n',
#        '[startDay = 1, endDay = 1, Segment = MALE_YOUNG, Reach = 1647, Budget = 1647.0]\n',
#        '[startDay = 1, endDay = 3, Segment = FEMALE_OLD_HIGH_INCOME, Reach = 854, Budget = 854.0]\n',
#        '[startDay = 1, endDay = 2, Segment = MALE_LOW_INCOME, Reach = 5083, Budget = 5083.0]\n',
#        '[startDay = 1, endDay = 1, Segment = MALE_YOUNG, Reach = 1176, Budget = 1176.0]\n',
#        '[startDay = 1, endDay = 1, Segment = FEMALE_OLD, Reach = 1404, Budget = 1404.0]\n',
#        '[startDay = 1, endDay = 3, Segment = MALE_YOUNG, Reach = 3529, Budget = 3529.0]\n',
#        '[startDay = 1, endDay = 2, Segment = OLD_LOW_INCOME, Reach = 4196, Budget = 4196.0]\n',
#        '[startDay = 1, endDay = 2, Segment = FEMALE_HIGH_INCOME, Reach = 397, Budget = 397.0]\n',
#        '[startDay = 1, endDay = 1, Segment = FEMALE_LOW_INCOME, Reach = 2190, Budget = 2190.0]\n',
#        '[startDay = 1, endDay = 3, Segment = MALE_OLD, Reach = 3904, Budget = 3904.0]\n',
#        '[startDay = 1, endDay = 2, Segment = MALE_LOW_INCOME, Reach = 2178, Budget = 2178.0]\n',
#        '[startDay = 1, endDay = 3, Segment = OLD_LOW_INCOME, Reach = 6294, Budget = 6294.0]\n',
#        '[startDay = 1, endDay = 2, Segment = FEMALE_YOUNG, Reach = 1341, Budget = 1341.0]\n',
#        '[startDay = 1, endDay = 3, Segment = MALE_LOW_INCOME, Reach = 7625, Budget = 7625.0]\n',
#        '[startDay = 1, endDay = 2, Segment = FEMALE_YOUNG_HIGH_INCOME, Reach = 153, Budget = 153.0]\n',
#        '[startDay = 1, endDay = 2, Segment = FEMALE_LOW_INCOME, Reach = 4381, Budget = 4381.0]\n',
#        '[startDay = 1, endDay = 1, Segment = MALE_YOUNG_LOW_INCOME, Reach = 550, Budget = 550.0]\n',
#        '[startDay = 1, endDay = 1, Segment = FEMALE_LOW_INCOME, Reach = 1314, Budget = 1314.0]\n',
#        '[startDay = 1, endDay = 3, Segment = MALE_OLD, Reach = 2342, Budget = 2342.0]\n',
#        '[startDay = 1, endDay = 2, Segment = MALE_YOUNG_LOW_INCOME, Reach = 1836, Budget = 1836.0]\n',
#        '[startDay = 1, endDay = 1, Segment = FEMALE_OLD_HIGH_INCOME, Reach = 122, Budget = 122.0]\n',
#        '[startDay = 1, endDay = 1, Segment = OLD_LOW_INCOME, Reach = 2937, Budget = 2937.0]\n',
#        '[startDay = 1, endDay = 3, Segment = MALE_YOUNG_HIGH_INCOME, Reach = 465, Budget = 465.0]\n',
#        '[startDay = 1, endDay = 3, Segment = MALE_YOUNG_LOW_INCOME, Reach = 3855, Budget = 3855.0]\n',
#        '[startDay = 1, endDay = 2, Segment = MALE_YOUNG, Reach = 3294, Budget = 3294.0]\n',
#        '[startDay = 1, endDay = 3, Segment = OLD_LOW_INCOME, Reach = 8811, Budget = 8811.0]\n',
#        '[startDay = 1, endDay = 3, Segment = OLD_HIGH_INCOME, Reach = 1093, Budget = 1093.0]\n',
#        '[startDay = 1, endDay = 2, Segment = YOUNG_HIGH_INCOME, Reach = 1082, Budget = 1082.0]\n',
#        '[startDay = 1, endDay = 3, Segment = FEMALE_YOUNG, Reach = 4695, Budget = 4695.0]\n',
#        '[startDay = 1, endDay = 2, Segment = OLD_LOW_INCOME, Reach = 2517, Budget = 2517.0]\n',
#        '[startDay = 1, endDay = 2, Segment = YOUNG_HIGH_INCOME, Reach = 773, Budget = 773.0]\n',
#        '[startDay = 1, endDay = 2, Segment = MALE_YOUNG_HIGH_INCOME, Reach = 723, Budget = 723.0]\n',
#        '[startDay = 1, endDay = 2, Segment = MALE_OLD_HIGH_INCOME, Reach = 484, Budget = 484.0]\n',
#        '[startDay = 1, endDay = 2, Segment = MALE_YOUNG, Reach = 1411, Budget = 1411.0]\n',
#        '[startDay = 1, endDay = 2, Segment = FEMALE_OLD, Reach = 1684, Budget = 1684.0]\n',
#        '[startDay = 1, endDay = 3, Segment = YOUNG_LOW_INCOME, Reach = 8013, Budget = 8013.0]\n',
#        '[startDay = 1, endDay = 2, Segment = MALE_YOUNG_HIGH_INCOME, Reach = 517, Budget = 517.0]\n',
#        '[startDay = 1, endDay = 2, Segment = MALE_YOUNG_LOW_INCOME, Reach = 1101, Budget = 1101.0]\n',
#        '[startDay = 1, endDay = 1, Segment = FEMALE_YOUNG_HIGH_INCOME, Reach = 128, Budget = 128.0]\n',
#        '[startDay = 1, endDay = 2, Segment = FEMALE_HIGH_INCOME, Reach = 928, Budget = 928.0]\n',
#        '[startDay = 1, endDay = 3, Segment = FEMALE_HIGH_INCOME, Reach = 994, Budget = 994.0]\n',
#        '[startDay = 1, endDay = 3, Segment = FEMALE_YOUNG_HIGH_INCOME, Reach = 537, Budget = 537.0]\n',
#        '[startDay = 1, endDay = 2, Segment = MALE_OLD, Reach = 2603, Budget = 2603.0]\n',
#        '[startDay = 1, endDay = 1, Segment = FEMALE_YOUNG, Reach = 1565, Budget = 1565.0]\n',
#        '[startDay = 1, endDay = 2, Segment = FEMALE_OLD, Reach = 2808, Budget = 2808.0]\n',
#        '[startDay = 1, endDay = 3, Segment = FEMALE_YOUNG_LOW_INCOME, Reach = 1782, Budget = 1782.0]\n',
#        '[startDay = 1, endDay = 2, Segment = MALE_OLD_LOW_INCOME, Reach = 1795, Budget = 1795.0]\n',
#        '[startDay = 1, endDay = 1, Segment = FEMALE_OLD_HIGH_INCOME, Reach = 203, Budget = 203.0]\n',
#        '[startDay = 1, endDay = 2, Segment = MALE_YOUNG_HIGH_INCOME, Reach = 310, Budget = 310.0]\n',
#        '[startDay = 1, endDay = 2, Segment = OLD_HIGH_INCOME, Reach = 1215, Budget = 1215.0]\n',
#        '[startDay = 1, endDay = 3, Segment = OLD_HIGH_INCOME, Reach = 2551, Budget = 2551.0]\n',
#        '[startDay = 1, endDay = 1, Segment = MALE_OLD, Reach = 1301, Budget = 1301.0]\n',
#        '[startDay = 8, endDay = 8, Segment = MALE_YOUNG_LOW_INCOME, Reach = 1285, Budget = 406.33514232811564]\n',
#        '[startDay = 10, endDay = 10, Segment = OLD_HIGH_INCOME, Reach = 850, Budget = 298.50044597435885]\n',
#        '[startDay = 10, endDay = 10, Segment = MALE_YOUNG_HIGH_INCOME, Reach = 361, Budget = 109.29771732857813]\n',
#        '[startDay = 7, endDay = 7, Segment = FEMALE_YOUNG_LOW_INCOME, Reach = 990, Budget = 308.72062207111196]\n',
#        '[startDay = 8, endDay = 8, Segment = MALE_OLD_LOW_INCOME, Reach = 1256, Budget = 410.55057574233217]\n'],
#       dtype=object)
